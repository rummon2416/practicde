# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_decision_regions
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.models import Dense
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[23], line 7
#       5 from sklearn.preprocessing import StandardScaler
#       6 from keras.models import Sequential
# ----> 7 from keras.models import Dense
#
# ImportError: cannot import name 'Dense' from 'keras.models' (C:\ProgramData\anaconda3\Lib\site-packages\keras\api\models\__init__.py)

# %%
dataset = pd.read_csv(r"C:\Users\Administrator\Downloads\Bank_Customer.csv")

# %%
dataset
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 0        15634602           619   France  Female   42       2       0.00
# 1        15647311           608    Spain  Female   41       1   83807.86
# 2        15619304           502   France  Female   42       8  159660.80
# 3        15701354           699   France  Female   39       1       0.00
# 4        15737888           850    Spain  Female   43       2  125510.82
# ...           ...           ...      ...     ...  ...     ...        ...
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %%
dataset.head(3)
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1

# %%
dataset.isnull().sum()
# Out:
# customer_id         0
# credit_score        0
# country             0
# gender              0
# age                 0
# tenure              0
# balance             0
# products_number     0
# credit_card         0
# active_member       0
# estimated_salary    0
# churn               0
# dtype: int64

# %%
dataset.shape
# Out:
# (10000, 12)

# %%
dataset.drop(columns=['country'], inplace=True)

# %%
dataset.drop(columns=['gender'], inplace=True)

# %%
dataset
# Out:
#       customer_id  credit_score  age  tenure    balance  products_number  \
# 0        15634602           619   42       2       0.00                1
# 1        15647311           608   41       1   83807.86                1
# 2        15619304           502   42       8  159660.80                3
# 3        15701354           699   39       1       0.00                2
# 4        15737888           850   43       2  125510.82                1
# ...           ...           ...  ...     ...        ...              ...
# 9995     15606229           771   39       5       0.00                2
# 9996     15569892           516   35      10   57369.61                1
# 9997     15584532           709   36       7       0.00                1
# 9998     15682355           772   42       3   75075.31                2
# 9999     15628319           792   28       4  130142.79                1
#
#       credit_card  active_member  estimated_salary  churn
# ...

# %%
x = dataset.drop(columns="churn", axis = 1)
y = dataset["churn"]

# %%
x
# Out:
#       customer_id  credit_score  age  tenure    balance  products_number  \
# 0        15634602           619   42       2       0.00                1
# 1        15647311           608   41       1   83807.86                1
# 2        15619304           502   42       8  159660.80                3
# 3        15701354           699   39       1       0.00                2
# 4        15737888           850   43       2  125510.82                1
# ...           ...           ...  ...     ...        ...              ...
# 9995     15606229           771   39       5       0.00                2
# 9996     15569892           516   35      10   57369.61                1
# 9997     15584532           709   36       7       0.00                1
# 9998     15682355           772   42       3   75075.31                2
# 9999     15628319           792   28       4  130142.79                1
#
#       credit_card  active_member  estimated_salary
# ...

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: churn, Length: 10000, dtype: int64

# %%
ss = StandardScaler()
x = pd.DataFrame(ss.fit_transform(x),columns=x.columns)

# %%
x
# Out:
#       customer_id  credit_score       age    tenure   balance  \
# 0       -0.783213     -0.326221  0.293517 -1.041760 -1.225848
# 1       -0.606534     -0.440036  0.198164 -1.387538  0.117350
# 2       -0.995885     -1.536794  0.293517  1.032908  1.333053
# 3        0.144767      0.501521  0.007457 -1.387538 -1.225848
# 4        0.652659      2.063884  0.388871 -1.041760  0.785728
# ...           ...           ...       ...       ...       ...
# 9995    -1.177652      1.246488  0.007457 -0.004426 -1.225848
# 9996    -1.682806     -1.391939 -0.373958  1.724464 -0.306379
# 9997    -1.479282      0.604988 -0.278604  0.687130 -1.225848
# 9998    -0.119356      1.256835  0.293517 -0.695982 -0.022608
# 9999    -0.870559      1.463771 -1.041433 -0.350204  0.859965
#
#       products_number  credit_card  active_member  estimated_salary
# 0           -0.911583     0.646092       0.970243          0.021886
# 1           -0.911583    -1.547768       0.970243          0.216534
# ...

# %%
pip install keras
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
x
# Out:
#       customer_id  credit_score       age    tenure   balance  \
# 0       -0.783213     -0.326221  0.293517 -1.041760 -1.225848
# 1       -0.606534     -0.440036  0.198164 -1.387538  0.117350
# 2       -0.995885     -1.536794  0.293517  1.032908  1.333053
# 3        0.144767      0.501521  0.007457 -1.387538 -1.225848
# 4        0.652659      2.063884  0.388871 -1.041760  0.785728
# ...           ...           ...       ...       ...       ...
# 9995    -1.177652      1.246488  0.007457 -0.004426 -1.225848
# 9996    -1.682806     -1.391939 -0.373958  1.724464 -0.306379
# 9997    -1.479282      0.604988 -0.278604  0.687130 -1.225848
# 9998    -0.119356      1.256835  0.293517 -0.695982 -0.022608
# 9999    -0.870559      1.463771 -1.041433 -0.350204  0.859965
#
#       products_number  credit_card  active_member  estimated_salary
# 0           -0.911583     0.646092       0.970243          0.021886
# 1           -0.911583    -1.547768       0.970243          0.216534
# ...

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: churn, Length: 10000, dtype: int64

# %%
ann= Sequential()

# %%
from keras.models import Sequential
from keras.layers import Dense

# Initialize the neural network model
ann = Sequential()

# Add layers to the model
ann.add(Dense(6, input_dim=8, activation="relu"))  # Input layer with 8 input features
ann.add(Dense(4, activation="relu"))              # Hidden layer 1 with 6 neurons
ann.add(Dense(2, activation="relu"))              # Hidden layer 2 with 4 neurons
ann.add(Dense(1, activation="sigmoid"))           # Output layer with 1 neuron
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
